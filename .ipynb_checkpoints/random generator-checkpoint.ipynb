# %%
#Packages
import h5py
import os
import numpy as np    
import matplotlib.pyplot as plt
from scipy.constants import pi
from scipy.optimize import curve_fit as fit
import func as func
import random
from tqdm import tqdm

# %%
n = 32700

x1, x2 = 0, 50000
y1, y2 = 0, 50000
z1, z2 = 0, 50000

x = (x2 - x1)*np.random.rand(n) + x1
y = (y2 - y1)*np.random.rand(n) + y1
z = (z2 - z1)*np.random.rand(n) + z1

fig = plt.figure(dpi=200)
ax = plt.axes(projection='3d')
plot = ax.scatter3D(x,y,z,'k.',s=0.5,alpha=0.1)
plt.show()

# %%
# Number of particles involved in randomization:
n = 1000

# Setting limits for each coordinate:
x1, x2 = 0, 50000
y1, y2 = 0, 50000
z1, z2 = 0, 50000

# Defining the final coordinate vectors randomly:
x = (x2 - x1)*np.random.rand(n) + x1
y = (y2 - y1)*np.random.rand(n) + y1
z = (z2 - z1)*np.random.rand(n) + z1

# Same measuring block as before, histogram making looping each particle:
dmax=np.sqrt(3)*50000

histrand=[]
histrand=np.array(histrand)
 
for j in tqdm(range(100)):
    d=[]
    for i in range(1,n):
        r=func.distance(x[j],x[i],x[j],x[i],x[j],x[i])
        d=np.append(d,r)
    output=np.histogram(d,bins=100,range=(0,dmax))
    counts=output[0]
    n=np.array(counts)
    histrand=np.concatenate((histrand,counts),axis=0)
histrand=np.split(histrand,1000)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-d2c9e7ebebc2> in <module>
#      21     d=[]
#      22     for i in range(1,n):
# ---> 23         r=func.distance(x[j],x[i],x[j],x[i],x[j],x[i])
#      24         d=np.append(d,r)
#      25     output=np.histogram(d,bins=100,range=(0,dmax))
#
# AttributeError: module 'func' has no attribute 'distance'
